# %%
import cv2
import numpy as np
import pickle
from sklearn.model_selection import train_test_split

# %%
with_mask = np.load('with_mask.npy')
without_mask = np.load('without_mask.npy')

# %%
with_mask = with_mask.reshape(201, 50 * 50 * 3)
without_mask = without_mask.reshape(202,50 * 50 * 3)

# %%
haar_data = cv2.CascadeClassifier('data.xml')

# %%
X = np.r_[with_mask,without_mask]

# %%
label = np.zeros(X.shape[0])

# %%
label[200:] = 1.0

# %%
x_train, x_test ,y_train, y_test = train_test_split(X,label,test_size=0.25)

# %%
filename = 'finalized_model.sav'
loaded_model = pickle.load(open(filename, 'rb'))
#result = loaded_model.score(X_test, Y_test)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
x_train = pca.fit_transform(x_train)

# %%
x_test = pca.transform(x_test)
y_pred = loaded_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test , y_pred)
# Out:
# 0.9702970297029703

# %%
names = {0:'Mask',1:'No Mask'}

# %%
haar_data = cv2.CascadeClassifier('data.xml')
capture = cv2.VideoCapture(0)
data = []
font = cv2.FONT_HERSHEY_COMPLEX
while True:
    flag,img = capture.read()
    if flag:
        faces = haar_data.detectMultiScale(img)
        for x,y,w,h in faces:
            cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,255),4)
            face = img[y:y+h,x:x+w,:]
            face = cv2.resize(face,(50,50))
            face = face.reshape(1,-1)
            face = pca.transform(face)
            pred = loaded_model.predict(face)[0]
            n = names[int(pred)]
            cv2.putText(img,n,(x,y),font,1,(244,250,250),2)
            print(n)
        cv2.imshow('result',img)
        if cv2.waitKey(2) == 27 :
            break
capture.release()
cv2.destroyAllWindows()
# Out:
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# No Mask
# Mask
# No Mask
# Mask
# Mask
# Mask
# No Mask
# Mask
# Mask
# Mask
# No Mask
# Mask
# Mask
# Mask
# No Mask
# Mask
# Mask
# Mask
# No Mask
# Mask
# No Mask
# Mask
# No Mask
# Mask
# No Mask
# Mask
# Mask
# No Mask
# No Mask
# No Mask
# No Mask
# Mask
# No Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# No Mask
# Mask
# No Mask
# Mask
# No Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# No Mask
# No Mask
# Mask
# No Mask
# Mask
# Mask
# No Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# No Mask
# Mask
# Mask
# No Mask
# Mask
# Mask
# No Mask
# Mask
# No Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# No Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# No Mask
# Mask
# No Mask
# Mask
# No Mask
# Mask
# Mask
# No Mask
# No Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# Mask
# No Mask
# No Mask
# Mask
# No Mask
# No Mask
# No Mask
# No Mask
# Mask
# No Mask
# Mask
# No Mask
# Mask
# Mask
# No Mask
# Mask
# Mask
# Mask
# No Mask
# No Mask
# No Mask
# Mask
# No Mask
# No Mask
# Mask
# No Mask
# Mask
# Mask
# Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask

# %%
test_image='./11jpg'

# %%
face=haar_data.detectMultiScale(img1)
face = cv2.resize(face,(50,50))
face = face.reshape(1,-1)
face = pca.transform(face)
pred = loaded_model.predict(face)[0]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-18-d934eaccfdb9> in <module>
# ----> 1 face=haar_data.detectMultiScale(img1)
#       2 face = cv2.resize(face,(50,50))
#       3 face = face.reshape(1,-1)
#       4 face = pca.transform(face)
#       5 pred = loaded_model.predict(face)[0]
#
# error: OpenCV(4.5.3) :-1: error: (-5:Bad argument) in function 'detectMultiScale'
# > Overload resolution failed:
# >  - image is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'image'

# %%
test_image=image.img_to_array(test_image)
test_image=np.expand_dims(test_image,axis=0)
pred=mymodel.predict(test_image)[0][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f40aa0696ea4> in <module>
# ----> 1 test_image=image.img_to_array(test_image)
#       2 test_image=np.expand_dims(test_image,axis=0)
#       3 pred=mymodel.predict(test_image)[0][0]
#
# NameError: name 'image' is not defined
